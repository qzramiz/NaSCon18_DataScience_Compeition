# %%
import pandas as pd
import numpy as np

# %%
df  = pd.read_csv("Patient_Records_Train.csv")
df['Additional diagnoses'] = df['Additional diagnoses'].str.lower()

# %%
pd.options.display.max_columns =100

# %%
np.unique(df['Disease'])
# Out:
# array(['Bundle branch block', 'Cardiomyopathy', 'Dysrhythmia',
#        'Healthy control', 'Hypertrophy', 'Myocardial infarction',
#        'Myocarditis', 'Unidentified', 'Valvular heart disease'], dtype=object)

# %%
df[df['patientID']==102]
# Out:
#     patientID Acute infarction (localization) Additional diagnoses  \
# 14        102                              no       atrial flutter
#
#    Additional medication Admission date  Aorta (at rest) diast  \
# 14                   n/a            NaN                    NaN
#
#     Aorta (at rest) mean  Aorta (at rest) syst  Cardiac index (at rest)  \
# 14                   NaN                   NaN                      NaN
#
#     Cardiac index (load)  Cardiac output (at rest)  Cardiac output (load)  \
# 14                   NaN                       NaN                    NaN
#
#    Catheterization date  Chest X-ray Dosage (lytic agent)  ECG date  \
# 14                  NaN          NaN                  n/a       7.0
#
#    Echocardiography Former infarction (localization) In hospital medication  \
# 14              n/a                               no                    n/a
#
#    Infarction date Infarction date (acute)  \
# 14             NaN                     NaN
#
# ...

# %%
df[df['Disease'] == 'Dysrhythmia']
# Out:
#      patientID Acute infarction (localization)  \
# 14         102                              no
# 40          83                              no
# 44         242                              no
# 50         221                              no
# 61         112                              no
# 62          54                              no
# 122         22                              no
# 152        199                              no
#
#                                   Additional diagnoses Additional medication  \
# 14                                      atrial flutter                   n/a
# 40    atrial fibrillation, heart failure (nyha 2-3)...                   n/a
# 44    atrial fibrillation, prosthetic valve in mitr...                   n/a
# 50                        congenital complete av-block                   n/a
# 61         palpitation, arterial hypertension, obesity                   n/a
# ...

# %%
print df.columns
# Out:
# Index([u'patientID', u'Acute infarction (localization)',
#        u'Additional diagnoses', u'Additional medication', u'Admission date',
#        u'Aorta (at rest) diast', u'Aorta (at rest) mean',
#        u'Aorta (at rest) syst', u'Cardiac index (at rest)',
#        u'Cardiac index (load)', u'Cardiac output (at rest)',
#        u'Cardiac output (load)', u'Catheterization date', u'Chest X-ray',
#        u'Dosage (lytic agent)', u'ECG date', u'Echocardiography',
#        u'Former infarction (localization)', u'In hospital medication',
#        u'Infarction date', u'Infarction date (acute)',
#        u'Left coronary artery stenoses (RCX)',
#        u'Left coronary artery stenoses (RIVA)',
#        u'Left ventricular enddiastolic pressure', u'Lytic agent',
#        u'Medication after discharge', u'Medication pre admission',
#        u'Number of coronary vessels involved',
#        u'Peripheral blood Pressure diast', u'Peripheral blood Pressure syst',
# ...

# %%
s,c = np.unique(list(df[df['Number of coronary vessels involved']> 0]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Bundle branch block' 'Cardiomyopathy' 'Hypertrophy'
#  'Myocardial infarction'] [ 1  1  1 76]

# %%
s,c = np.unique(list(df[~(df['In hospital medication'].str.contains('n/a'))]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Myocardial infarction'] [72]

# %%
s,c = np.unique(list(df[df['Additional diagnoses'].str.contains('gradient')]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Cardiomyopathy' 'Valvular heart disease'] [3 1]

# %%
 for h in df[df['Additional diagnoses'].str.contains('gradient')]['Additional diagnoses']:
        print h
# Out:
#  recurrent pulmonary oedema, hypertrophic obstructive cardiomyopathy (intraventricular gradient 70-90mmhg), hyperlipoproteinemia, diabetes mellitus, obesity
#  synkope, stable angina, aortic stenosis (gradient 90mmhg), varicosis
#  hypertropic obstructive cardiomyopathy (intraventricular gradient 70mmhg)
#  heart failure (nyha 3), hypertrophic obstructive cardiomyopathy (intraventricular gradient 100-160mmhg)

# %%
s,c = np.unique(list(df[df['Additional diagnoses'].str.contains('aortic')]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Hypertrophy' 'Myocardial infarction' 'Valvular heart disease'] [2 1 3]

# %%
s,c = np.unique(list(df[df['Additional diagnoses'].str.contains('palpitation')]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Dysrhythmia' 'Myocardial infarction'] [1 1]

# %%
s,c = np.unique(list(df[df['Additional diagnoses'].str.contains('palpitation')]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Dysrhythmia' 'Myocardial infarction'] [1 1]

# %%
df[df['Disease'].str.contains('Dysrhythmia')]
# Out:
#      patientID Acute infarction (localization)  \
# 14         102                              no
# 40          83                              no
# 44         242                              no
# 50         221                              no
# 61         112                              no
# 62          54                              no
# 122         22                              no
# 152        199                              no
#
#                                   Additional diagnoses Additional medication  \
# 14                                      atrial flutter                   n/a
# 40    atrial fibrillation, heart failure (nyha 2-3)...                   n/a
# 44    atrial fibrillation, prosthetic valve in mitr...                   n/a
# 50                        congenital complete av-block                   n/a
# 61         palpitation, arterial hypertension, obesity                   n/a
# ...

# %%
df[df['Additional diagnoses'].str.contains('asthma')]
# Out:
#     patientID Acute infarction (localization)  \
# 60         91                              no
#
#                                  Additional diagnoses Additional medication  \
# 60   hypertrophic (obstructive) cardiomyopathy, as...                   n/a
#
#    Admission date  Aorta (at rest) diast  Aorta (at rest) mean  \
# 60            NaN                    NaN                   NaN
#
#     Aorta (at rest) syst  Cardiac index (at rest)  Cardiac index (load)  \
# 60                   NaN                      NaN                   NaN
#
#     Cardiac output (at rest)  Cardiac output (load) Catheterization date  \
# 60                       NaN                    NaN            15-May-96
#
#     Chest X-ray Dosage (lytic agent)  ECG date  \
# 60          NaN                  n/a      21.0
#
#                                      Echocardiography  \
# 60   LV hypertrophy. E/A=0.8.Mitral regurgitation ...
#
# ...

# %%
s,c = np.unique(list(df[df['Additional diagnoses'].str.contains('regurgitation')]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Hypertrophy' 'Myocardial infarction' 'Valvular heart disease'] [1 2 3]

# %%
s,c = np.unique(list(df[df['Additional diagnoses'].str.contains('atrial flutter')]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Dysrhythmia'] [1]

# %%
s,c = np.unique(list(df[df['Additional diagnoses'].str.contains('atrial fibrillation')]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Cardiomyopathy' 'Dysrhythmia' 'Myocardial infarction'] [1 4 2]

# %%
s,c = np.unique(list(df[df['Additional diagnoses'].str.contains('no')]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Bundle branch block' 'Dysrhythmia' 'Healthy control' 'Hypertrophy'
#  'Myocardial infarction' 'Myocarditis' 'Valvular heart disease'] [ 3  1 28  1 23  1  2]

# %%
s,c = np.unique(list(df[df['Acute infarction (localization)'].str.contains('n/a')]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Unidentified'] [14]

# %%
s,c = np.unique(list(df[~((df['Acute infarction (localization)'].str.contains('n/a')) | (df['Acute infarction (localization)'].str.contains('no')))]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Myocardial infarction'] [85]

# %%
s,c = np.unique(list(df[df['Additional diagnoses'].str.contains('obesity')]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Cardiomyopathy' 'Dysrhythmia' 'Hypertrophy' 'Myocardial infarction'] [ 1  2  1 11]

# %%
s,c = np.unique(list(df[df['Additional diagnoses'].str.contains('obesity')]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Cardiomyopathy' 'Dysrhythmia' 'Hypertrophy' 'Myocardial infarction'] [ 1  2  1 11]

# %%
s,c = np.unique(list(df[df['Additional diagnoses'].str.contains('unknown')]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Myocardial infarction'] [8]

# %%
s,c = np.unique(list(df[df['Additional diagnoses'].str.contains('tachycardia')]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Cardiomyopathy' 'Myocardial infarction'] [1 5]

# %%
s,c = np.unique(list(df[df['Additional diagnoses'].str.contains('arterial hypertension')]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Bundle branch block' 'Dysrhythmia' 'Hypertrophy' 'Myocardial infarction'
#  'Myocarditis' 'Valvular heart disease'] [ 3  1  4 31  1  1]

# %%
s,c = np.unique(list(df[df['Additional diagnoses'].str.contains('regurgitation')]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Hypertrophy' 'Myocardial infarction' 'Valvular heart disease'] [1 2 3]

# %%
s,c = np.unique(list(df[df['Additional diagnoses'].str.contains('atrial fibrillation')]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Cardiomyopathy' 'Dysrhythmia' 'Myocardial infarction'] [1 4 2]

# %%
s,c = np.unique(list(df[df['Additional diagnoses'].str.contains('coronary artery disease')]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Bundle branch block' 'Hypertrophy' 'Myocardial infarction'] [1 1 5]

# %%
s,c = np.unique(list(df[df['Additional diagnoses'].str.contains('renal')]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Myocardial infarction'] [5]

# %%
s,c = np.unique(list(df[df['Additional diagnoses'].str.contains('cardiomyopathy')]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Bundle branch block' 'Cardiomyopathy' 'Myocardial infarction'] [1 8 3]

# %%
s,c = np.unique(list(df[~(df['Right coronary artery stenoses (RCA)'].str.contains('n/a'))]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Bundle branch block' 'Cardiomyopathy' 'Hypertrophy'
#  'Myocardial infarction'] [ 1  1  2 70]

# %%
df[(~(df['Right coronary artery stenoses (RCA)'].str.contains('n/a')) & (df['Acute infarction (localization)'].str.contains('no')))]
# Out:
#     patientID Acute infarction (localization)  \
# 27        282                              no
# 56        208                              no
# 60         91                              no
# 68        217                              no
#
#                                  Additional diagnoses Additional medication  \
# 27   arterial hypertension, minimal aortic regurgi...                   n/a
# 56   coronary artery disease, diabetes mellitus, a...                   n/a
# 60   hypertrophic (obstructive) cardiomyopathy, as...                   n/a
# 68   coronary artery disease, post ptca and stent ...                   n/a
#
#    Admission date  Aorta (at rest) diast  Aorta (at rest) mean  \
# 27            NaN                    NaN                   NaN
# 56            NaN                    NaN                   NaN
# 60            NaN                    NaN                   NaN
# 68            NaN                    NaN                   NaN
#
# ...

# %%
s,c = np.unique(list(df[~(df['Lytic agent'].str.contains('n/a'))]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Bundle branch block' 'Myocardial infarction'] [ 1 69]

# %%
df[(df['Lytic agent'].str.contains('Enalapril'))]
# Out:
# Empty DataFrame
# ...

# %%
(df[df['Additional diagnoses'].str.contains('ongenital complete av-block')])
# Out:
#     patientID Acute infarction (localization)           Additional diagnoses  \
# 50        221                              no   congenital complete av-block
#
#    Additional medication Admission date  Aorta (at rest) diast  \
# 50                   n/a            NaN                    NaN
#
#     Aorta (at rest) mean  Aorta (at rest) syst  Cardiac index (at rest)  \
# 50                   NaN                   NaN                      NaN
#
#     Cardiac index (load)  Cardiac output (at rest)  Cardiac output (load)  \
# 50                   NaN                       NaN                    NaN
#
#    Catheterization date  Chest X-ray Dosage (lytic agent)  ECG date  \
# 50                  NaN          NaN                  n/a      19.0
#
#    Echocardiography Former infarction (localization) In hospital medication  \
# 50              n/a                               no                    n/a
#
#    Infarction date Infarction date (acute)  \
# ...

# %%
#renal insufficiency, arterial hypertension
list(df[df['Additional diagnoses'].str.contains('diabetes mellitus')]['Additional diagnoses'])
# Out:
# [' diabetes mellitus',
#  ' hyperlipoproteinemia type iv b, diabetes mellitus, peripheral atherosclerosis, arterial hypertension, cerebral stroke, colon cancer',
#  ' recurrent pulmonary oedema, hypertrophic obstructive cardiomyopathy (intraventricular gradient 70-90mmhg), hyperlipoproteinemia, diabetes mellitus, obesity',
#  ' diabetes mellitus, renal insufficiency',
#  ' diabetes mellitus, hyperuricemia',
#  ' diabetes mellitus',
#  ' coronary artery disease, diabetes mellitus, arterial hypertension',
#  ' diabetes mellitus, hyperlipoproteinemia type iia',
#  ' coronary artery disease, post ptca and stent (riva), arterial hypertension, diabetes mellitus, calcified aortic valve (mild stenosis), hyperlipoproteinemia',
#  ' diabetes mellitus, arterial hypertension, obesity',
#  ' arterial hypertension, diabetes mellitus ',
#  ' arterial hypertension, diabetes mellitus',
# ...

# %%
s,c = np.unique(list(df[df['Right coronary artery stenoses (RCA)'].str.contains('n/a')]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Bundle branch block' 'Cardiomyopathy' 'Dysrhythmia' 'Healthy control'
#  'Hypertrophy' 'Myocardial infarction' 'Myocarditis' 'Unidentified'
#  'Valvular heart disease'] [ 6  7  8 28  2 28  2 14  4]

# %%
s,c = np.unique(list(df[~((df['Ventriculography'].str.contains('n/a')) | (df['Ventriculography'].str.contains('no')))]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Bundle branch block' 'Hypertrophy' 'Myocardial infarction'] [ 1  2 59]

# %%
df[df['Ventriculography'].str.contains('not')]
# Out:
#      patientID Acute infarction (localization)  \
# 12         278                  infero-lateral
# 32         130                  infero-lateral
# 59          84          infero-postero-lateral
# 92         128                        inferior
# 116        223                   antero-septal
# 135         73                  antero-lateral
# 169         55                       posterior
#
#                                   Additional diagnoses  \
# 12            nephrotic syndrome, rheumatoid arthritis
# 32    arterial hypertension, hyperlipemia, ventricu...
# 59                                                  no
# 92            arterial hypertension, diabetes mellitus
# 116                         peripheral atherosclerosis
# 135                 diabetes mellitus, hyperthyroidism
# 169   arterial hypertension, diabetes mellitus, hyp...
#
#                                  Additional medication Admission date  \
# ...

# %%
s,c = np.unique(list(df[~(df['Former infarction (localization)'].str.contains('no'))]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Myocardial infarction' 'Unidentified'] [30 14]

# %%
df[~(df['Former infarction (localization)'].str.contains('no'))]
# Out:
#      patientID Acute infarction (localization)  \
# 6          195                             n/a
# 10          13                        inferior
# 11          53                              no
# 15         186                  antero-lateral
# 16          56                             n/a
# 17         147                             n/a
# 20         111                   antero-septal
# 24          35                             n/a
# 28         265                              no
# 29          52            antero-septo-lateral
# 33          26                        anterior
# 36         209                  infero-lateral
# 37          81                              no
# 43         216                              no
# 45          47                              no
# 52          11                        inferior
# 53         289                        anterior
# 58         175                              no
# 63         205                   antero-septal
# ...

# %%
s,c = np.unique(list(df[df['Echocardiography'].str.contains('hypertrophy')]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Bundle branch block' 'Cardiomyopathy' 'Hypertrophy'
#  'Myocardial infarction'] [1 1 1 1]

# %%
#coronary artery disease, arterial hypertension atrial fibrillation, diabetes mellitus
df[((df['Additional diagnoses'].str.contains('atrial fibrillation')) | (df['Additional diagnoses'].str.contains('diabetes mellitus')))]
# Out:
#      patientID Acute infarction (localization)  \
# 1           16          infero-postero-lateral
# 36         209                  infero-lateral
# 40          83                              no
# 42         201                              no
# 44         242                              no
# 46         279                 postero-lateral
# 47         273                  infero-lateral
# 52          11                        inferior
# 56         208                              no
# 58         175                              no
# 63         205                   antero-septal
# 68         217                              no
# 69          76                  antero-lateral
# 80         120                              no
# 87         258                  infero-lateral
# 92         128                        inferior
# 122         22                              no
# 133        256                              no
# 135         73                  antero-lateral
# ...

# %%
s,c = np.unique(list(df[~(df['Catheterization date'].isnull())]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Bundle branch block' 'Cardiomyopathy' 'Hypertrophy'
#  'Myocardial infarction'] [ 1  1  2 73]

# %%
df[((df['Additional diagnoses'].str.contains('cardiomyopathy')) & (df['Additional diagnoses'].str.contains('ventricular')))]
# Out:
#      patientID Acute infarction (localization)  \
# 42         201                              no
# 119        262                              no
# 121        191                              no
# 136        292                              no
# 146        155                              no
#
#                                   Additional diagnoses Additional medication  \
# 42    recurrent pulmonary oedema, hypertrophic obst...                   n/a
# 119   hypertropic obstructive cardiomyopathy (intra...                   n/a
# 121   dilated cardiomyopathy, recurrent ventricular...                   n/a
# 136   heart failure (nyha 3), hypertrophic obstruct...                   n/a
# 146   recurrent ventricular tachycardia, dilated ca...                   n/a
#
#     Admission date  Aorta (at rest) diast  Aorta (at rest) mean  \
# 42             NaN                    NaN                   NaN
# 119            NaN                    NaN                   NaN
# ...

# %%
s,c = np.unique(list(df[df['Ventriculography'].str.contains('not')]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Myocardial infarction'] [7]

# %%
np.unique(g['patientID'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-109-8e28a9666986> in <module>()
# ----> 1 np.unique(g['patientID'])
#
# NameError: name 'g' is not defined

# %%
s,c = np.unique(list(df[df['Ventriculography'].str.contains('normal')]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Myocardial infarction'] [7]

# %%
s,c = np.unique(list(df[df['Smoker'].str.contains('yes')]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Cardiomyopathy' 'Hypertrophy' 'Myocardial infarction'] [ 2  1 42]

# %%
len(df[df['Disease'] == 'Healthy control'])
# Out:
# 28

# %%
list(df[df['Disease'] == 'Bundle branch block']['Echocardiography'])
# Out:
# [' n/a',
#  ' Pericardial effusion 7mm, ',
#  ' n/a',
#  ' no Echo',
#  ' Significantly enlarged LV (81mm) with decreased contractility (FS 12%). Mitral regurgitation (grade 2-3), moderately enlarged left atrium (49mm). Pericardial effusion (ca. 4mm)',
#  ' n/a',
#  ' LV hypertrophy, slightly diminuished contractility, Hypokinesia od the interventricular septum (12mm). Left atrium slightly enlarged (50mm), normal valves']

# %%
s,c = np.unique(list(df[~((df['Lytic agent'].str.contains('n/a')) | (df['Lytic agent'].str.contains('no')))]['Disease']),return_counts = True) 
print s,c
# Out:
# ['Bundle branch block' 'Myocardial infarction'] [ 1 69]

# %%
df[~((df['Lytic agent'].str.contains('n/a')) | (df['Lytic agent'].str.contains('no')))]
# Out:
#      patientID Acute infarction (localization)  \
# 0          159           infero-poster-lateral
# 3          193                  antero-lateral
# 4          115                        anterior
# 8          174                        inferior
# 10          13                        inferior
# 12         278                  infero-lateral
# 15         186                  antero-lateral
# 18         284                  antero-lateral
# 19          44                  infero-lateral
# 20         111                   antero-septal
# 21         152                   antero-septal
# 25         113                        inferior
# 31         219                        inferior
# 32         130                  infero-lateral
# 33          26                        anterior
# 34          65                  infero-lateral
# 35         271                        inferior
# 36         209                  infero-lateral
# 39         241                        inferior
# ...

# %%
df[df['Disease'] == 'Myocarditis']
# Out:
#     patientID Acute infarction (localization)    Additional diagnoses  \
# 30        108                              no                      no
# 38        158                              no   arterial hypertension
#
#    Additional medication Admission date  Aorta (at rest) diast  \
# 30                   n/a            NaN                    NaN
# 38                   n/a            NaN                    NaN
#
#     Aorta (at rest) mean  Aorta (at rest) syst  Cardiac index (at rest)  \
# 30                   NaN                   NaN                      NaN
# 38                   NaN                   NaN                      NaN
#
#     Cardiac index (load)  Cardiac output (at rest)  Cardiac output (load)  \
# 30                   NaN                       NaN                    NaN
# 38                   NaN                       NaN                    NaN
#
#    Catheterization date  Chest X-ray Dosage (lytic agent)  ECG date  \
# ...

# %%
df[df['Additional medication'].str.contains('n/a')]
# Out:
#      patientID Acute infarction (localization)  \
# 1           16          infero-postero-lateral
# 2          100                              no
# 6          195                             n/a
# 7            9                              no
# 9          243                              no
# 11          53                              no
# 13          12                  antero-lateral
# 14         102                              no
# 16          56                             n/a
# 17         147                             n/a
# 22         146                              no
# 23         101                              no
# 24          35                             n/a
# 26         207                              no
# 27         282                              no
# 28         265                              no
# 29          52            antero-septo-lateral
# 30         108                              no
# 37          81                              no
# ...

# %%
df
# Out:
#      patientID Acute infarction (localization)  \
# 0          159           infero-poster-lateral
# 1           16          infero-postero-lateral
# 2          100                              no
# 3          193                  antero-lateral
# 4          115                        anterior
# 5            3                        inferior
# 6          195                             n/a
# 7            9                              no
# 8          174                        inferior
# 9          243                              no
# 10          13                        inferior
# 11          53                              no
# 12         278                  infero-lateral
# 13          12                  antero-lateral
# 14         102                              no
# 15         186                  antero-lateral
# 16          56                             n/a
# 17         147                             n/a
# 18         284                  antero-lateral
# ...

# %%
df[df['Disease']=='Cardiomyopathy']
# Out:
#      patientID Acute infarction (localization)  \
# 42         201                              no
# 60          91                              no
# 119        262                              no
# 121        191                              no
# 136        292                              no
# 137         51                              no
# 143         34                              no
# 150         46                              no
#
#                                   Additional diagnoses Additional medication  \
# 42    recurrent pulmonary oedema, hypertrophic obst...                   n/a
# 60    hypertrophic (obstructive) cardiomyopathy, as...                   n/a
# 119   hypertropic obstructive cardiomyopathy (intra...                   n/a
# 121   dilated cardiomyopathy, recurrent ventricular...                   n/a
# 136   heart failure (nyha 3), hypertrophic obstruct...                   n/a
# ...

# %%
df[df['Disease']=='Hypertrophy']
# Out:
#     patientID Acute infarction (localization)  \
# 26        207                              no
# 27        282                              no
# 68        217                              no
# 98         61                              no
#
#                                  Additional diagnoses Additional medication  \
# 26   arterial hypertension, hyperlipoproteinemia, ...                   n/a
# 27   arterial hypertension, minimal aortic regurgi...                   n/a
# 68   coronary artery disease, post ptca and stent ...                   n/a
# 98                              arterial hypertension                   n/a
#
#    Admission date  Aorta (at rest) diast  Aorta (at rest) mean  \
# 26            NaN                    NaN                   NaN
# 27            NaN                    NaN                   NaN
# 68            NaN                    NaN                   NaN
# 98            NaN                    NaN                   NaN
#
# ...

# %%
print len(df)
print len(df[df['Disease']=='Unidentified'])
print len(df[df['Disease']=='Myocardial infarction'])
print len(df[df['Disease']=='Bundle branch block'])
print len(df[df['Disease']=='Cardiomyopathy'])
print len(df[df['Disease']=='Dysrhythmia'])
print len(df[df['Disease']=='Healthy control'])
print len(df[df['Disease']=='Myocarditis'])
print len(df[df['Disease']=='Valvular heart disease'])
print len(df[df['Disease']=='Hypertrophy'])
# Out:
# 173
# 14
# 98
# 7
# 8
# 8
# 28
# 2
# 4
# 4

# %%
df[df['Disease']=='Cardiomyopathy']
# Out:
#      patientID Acute infarction (localization)  \
# 42         201                              no
# 60          91                              no
# 119        262                              no
# 121        191                              no
# 136        292                              no
# 137         51                              no
# 143         34                              no
# 150         46                              no
#
#                                   Additional diagnoses Additional medication  \
# 42    recurrent pulmonary oedema, hypertrophic obst...                   n/a
# 60    hypertrophic (obstructive) cardiomyopathy, as...                   n/a
# 119   hypertropic obstructive cardiomyopathy (intra...                   n/a
# 121   dilated cardiomyopathy, recurrent ventricular...                   n/a
# 136   heart failure (nyha 3), hypertrophic obstruct...                   n/a
# ...

# %%
df[df['Disease']=='Dysrhythmia']
# Out:
#      patientID Acute infarction (localization)  \
# 14         102                              no
# 40          83                              no
# 44         242                              no
# 50         221                              no
# 61         112                              no
# 62          54                              no
# 122         22                              no
# 152        199                              no
#
#                                   Additional diagnoses Additional medication  \
# 14                                      atrial flutter                   n/a
# 40    atrial fibrillation, heart failure (nyha 2-3)...                   n/a
# 44    atrial fibrillation, prosthetic valve in mitr...                   n/a
# 50                        congenital complete av-block                   n/a
# 61         palpitation, arterial hypertension, obesity                   n/a
# ...

# %%
(df[df['Disease']=='Bundle branch block'])
# Out:
#      patientID Acute infarction (localization)  \
# 49         182                         unknown
# 56         208                              no
# 90         173                              no
# 101        275                              no
# 113         79                              no
# 138         36                              no
# 145         48                              no
#
#                                   Additional diagnoses Additional medication  \
# 49                                                  no                   n/a
# 56    coronary artery disease, diabetes mellitus, a...                   n/a
# 90                                           psoriasis                   n/a
# 101                             postop. rectum adenoma                   n/a
# 113   dilated cardiomyopathy, chronic glomeruloneph...                   n/a
# 138                                                 no                   n/a
# ...

# %%
(df[df['Disease']=='Myocarditis'])
# Out:
#     patientID Acute infarction (localization)    Additional diagnoses  \
# 30        108                              no                      no
# 38        158                              no   arterial hypertension
#
#    Additional medication Admission date  Aorta (at rest) diast  \
# 30                   n/a            NaN                    NaN
# 38                   n/a            NaN                    NaN
#
#     Aorta (at rest) mean  Aorta (at rest) syst  Cardiac index (at rest)  \
# 30                   NaN                   NaN                      NaN
# 38                   NaN                   NaN                      NaN
#
#     Cardiac index (load)  Cardiac output (at rest)  Cardiac output (load)  \
# 30                   NaN                       NaN                    NaN
# 38                   NaN                       NaN                    NaN
#
#    Catheterization date  Chest X-ray Dosage (lytic agent)  ECG date  \
# ...

# %%
s,c = np.unique(list(df[df['In hospital medication']]['Disease']),return_counts = True) 
print s,c
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-123-4ba5e35d55ed> in <module>()
# ----> 1 s,c = np.unique(list(df[df['In hospital medication']]['Disease']),return_counts = True)
#       2 print s,c
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    2175             return self._take(indexer, axis=0, convert=False)
#    2176         else:
# -> 2177             indexer = self.loc._convert_to_indexer(key, axis=1)
# ...

# %%
ff = list(df[(df['Disease'] == 'Cardiomyopathy')]['patientID'])

# %%
df['Additional diagnoses'] = df['Additional diagnoses'].str.lower()

# %%
ss = list(df[(df['Additional diagnoses'].str.contains('cardiomyopathy'))]['patientID'])

# %%
gg = np.setdiff1d(np.asarray(ss),ff)
print gg
# Out:
# [ 79 155 175 291]

# %%
gf = np.setdiff1d(np.asarray(ff),ss)
print gf
# Out:
# []

# %%
df[np.in1d(np.asarray(list(df['patientID'])),gg)]

# %%
list(df[(df['Disease'] == 'Cardiomyopathy')]['patientID'])

# %%
if['Acute infraction (lo)']

# %%
np.unique(f['patientID'])

# %%
df.sort_values('patientID')

# %%
np.unique(df['Disease'])

# %%
df.columns

# %%
df  = pd.read_csv("Patient_Records_Train.csv")

# %%
df
